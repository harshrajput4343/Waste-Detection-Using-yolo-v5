# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61/view?usp=share_link"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61'

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix + file_id, "data/waste_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61
# From (redirected): https://drive.google.com/uc?export=download&id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61&confirm=t&uuid=12357297-1768-4019-904a-261a7ff40d0c
# To: h:\Computer Vision project\Waste-Detection-Using-yolo-v5\Waste-Detection-Using-yolo-v5\data\waste_data.zip
# 100%|██████████| 40.1M/40.1M [00:09<00:00, 4.09MB/s]
# 'data/waste_data.zip'

# %%
# %pwd
# Out:
# 'h:\\Computer Vision project\\Waste-Detection-Using-yolo-v5\\Waste-Detection-Using-yolo-v5'

# %%
cd "h:\\Computer Vision project\\Waste-Detection-Using-yolo-v5\\Waste-Detection-Using-yolo-v5"
# Out:
# h:\Computer Vision project\Waste-Detection-Using-yolo-v5\Waste-Detection-Using-yolo-v5

# %% [markdown]
# ### if you want to change directory or go back to original directory
#  import os
#  os.chdir("h:\\Computer Vision project\\Waste-Detection-Using-yolo-v5\\Waste-Detection-Using-yolo-v5")
# os.chdir("../")
